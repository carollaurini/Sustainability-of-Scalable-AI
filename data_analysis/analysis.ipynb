# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# %%
#n=2
df2 = pd.read_csv("C:/Users/carol/Desktop/RadBoudCode/out_2.txt", sep =';',names = ['Bandwidth','Compute rate (GFLOPS)','Relative error','Runtime'])
df2['MAX_ITER'] = range(1,1001)
df2['N'] = 2
df2
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER  N
# 0    1.#INF00              1.#INF00    2.224737e+01    0.000         1  2
# 1    1.#INF00              1.#INF00    1.593264e+02    0.001         2  2
# 2    1.#INF00              1.#INF00    1.023370e+03    0.001         3  2
# 3    1.#INF00              1.#INF00    6.469650e+03    0.000         4  2
# 4    1.#INF00              1.#INF00    4.079891e+04    0.001         5  2
# ..        ...                   ...             ...      ...       ... ..
# 995  1.#INF00              1.#INF00   8.032376e+198    0.001       996  2
# 996  1.#INF00              1.#INF00   8.032376e+198    0.000       997  2
# 997  1.#INF00              1.#INF00   8.032376e+198    0.000       998  2
# 998  1.#INF00              1.#INF00   8.032376e+198    0.001       999  2
# 999  1.#INF00              1.#INF00   8.032376e+198    0.001      1000  2
#
# [1000 rows x 6 columns]

# %%
# Placing the plots in the plane
plot1 = plt.subplot2grid((6, 6), (0, 0), rowspan=2,colspan=2)
plot2 = plt.subplot2grid((6, 6), (0, 2), rowspan=4,colspan=2)
plot3 = plt.subplot2grid((6, 6), (2, 0), rowspan=2,colspan=2)
plot4 = plt.subplot2grid((6, 6), (0, 4), rowspan=4,colspan=2)
# Using Numpy to create an array x
x = np.arange(1, 1001)

# Plot for exponent
plot1.plot(x, df2['Bandwidth'],'.', markeredgewidth=0.02)
plot1.set_title('Bandwidth')
idx = np.round(np.linspace(0, len(df2['Bandwidth']) - 1, 10)).astype(int)
plot1.set(yticks=df2['Bandwidth'][idx])
plt.xlabel("Nº of interations for 2 x 2",fontsize=8)

# Plot for square root
plot4.plot(x, df2['Relative error'],'.', markeredgewidth=0.02)
plot4.set_yscale('log')
plot4.set_title('Relative error')



# Plot for Square
plot3.plot(x, df2['Compute rate (GFLOPS)'],'.', markeredgewidth=0.02)
plot3.set_title('Compute rate (GFLOPS)')
idx = np.round(np.linspace(0, len(df2['Compute rate (GFLOPS)']) - 1, 10)).astype(int)
plot3.set(yticks=df2['Compute rate (GFLOPS)'][idx])

# Plot for Square
plot2.plot(x, df2['Runtime'],'.', markeredgewidth=0.02)
plot2.set_title('Runtime (s)')
idx = np.round(np.linspace(0, len(df2['Relative error']) - 1, 10)).astype(int)
plot2.set(yticks=df2['Runtime'][idx])





# Packing all the plots and displaying them
plt.tight_layout()
plt.savefig('2.png', dpi=300, bbox_inches='tight')

# %%
df2_NaN = df2.replace(['1.#INF00','-1.#INF00'],np.nan)
df2_NaN = df2_NaN.dropna()
df2_NaN
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER  N
# 159  0.015361              0.007041   3.492802e+128    0.001       160  2
# 196  0.018950              0.008685   1.339856e+158    0.000       197  2
# 298  0.023901              0.010955   8.032376e+198    0.000       299  2
# 303  0.023878              0.010944   8.032376e+198    0.000       304  2
# 318  0.020092              0.009209   8.032376e+198    0.001       319  2
# 326  0.023907              0.010957   8.032376e+198    0.000       327  2
# 386  0.022005              0.010086   8.032376e+198    0.001       387  2
# 442  0.019484              0.008930   8.032376e+198    0.001       443  2
# 455  0.047259              0.021660   8.032376e+198    0.000       456  2
# 506  0.018686              0.008564   8.032376e+198    0.001       507  2
# 535  0.020334              0.009320   8.032376e+198    0.001       536  2
# 568  0.022628              0.010371   8.032376e+198    0.001       569  2
# ...

# %%
np.min(df2_NaN['Relative error'])
# Out:
# np.float64(3.492802e+128)

# %%
#n=3
df3 = pd.read_csv("C:/Users/carol/Desktop/RadBoudCode/out_3.txt", sep =';',names = ['Bandwidth','Compute rate (GFLOPS)','Relative error','Runtime'])
df3['MAX_ITER'] = range(1,1001)
df3['N'] = 3
df3
# Out:
#      Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER  N
# 0    -1.#INF00             -1.#INF00             1.0    0.000         1  3
# 1    -1.#INF00             -1.#INF00             1.0    0.000         2  3
# 2    -1.#INF00             -1.#INF00             1.0    0.000         3  3
# 3    -1.#INF00             -1.#INF00             1.0    0.001         4  3
# 4    -1.#INF00             -1.#INF00             1.0    0.000         5  3
# ..         ...                   ...             ...      ...       ... ..
# 995  -1.#INF00             -1.#INF00             1.0    0.000       996  3
# 996  -1.#INF00             -1.#INF00             1.0    0.001       997  3
# 997  -1.#INF00             -1.#INF00             1.0    0.000       998  3
# 998  -1.#INF00             -1.#INF00             1.0    0.001       999  3
# 999  -1.#INF00             -1.#INF00             1.0    0.000      1000  3
#
# [1000 rows x 6 columns]

# %%
df3_NaN = df3.replace(['1.#INF00','-1.#INF00'],np.nan)
df3_NaN = df3_NaN.dropna()
df3_NaN
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_16212\154674918.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df3_NaN = df3.replace(['-1.#INF00'],np.nan)
# Empty DataFrame
# Columns: [Bandwidth, Compute rate (GFLOPS), Relative error, Runtime, MAX_ITER, N]
# Index: []

# %%
# Placing the plots in the plane
plot1 = plt.subplot2grid((6, 6), (0, 0), rowspan=2,colspan=2)
plot2 = plt.subplot2grid((6, 6), (0, 2), rowspan=4,colspan=2)
plot3 = plt.subplot2grid((6, 6), (2, 0), rowspan=2,colspan=2)
plot4 = plt.subplot2grid((6, 6), (0, 4), rowspan=4,colspan=2)
# Using Numpy to create an array x
x = np.arange(1, 1001)

# Plot for exponent
plot1.plot(x, df3['Bandwidth'],'.', markeredgewidth=0.02)
plot1.set_title('Bandwidth')
idx = np.round(np.linspace(0, len(df3['Bandwidth']) - 1, 10)).astype(int)
plot1.set(yticks=df3['Bandwidth'][idx])
plt.xlabel("Nº of interations for 3 x 3",fontsize=8)

# Plot for square root
plot4.plot(x, df3['Relative error'],'.', markeredgewidth=0.02)
plot4.set_title('Relative error')



# Plot for Square
plot3.plot(x, df3['Compute rate (GFLOPS)'],'.', markeredgewidth=0.02)
plot3.set_title('Compute rate (GFLOPS)')
idx = np.round(np.linspace(0, len(df3['Compute rate (GFLOPS)']) - 1, 10)).astype(int)
plot3.set(yticks=df3['Compute rate (GFLOPS)'][idx])

# Plot for Square
plot2.plot(x, df3['Runtime'],'.', markeredgewidth=0.02)
plot2.set_title('Runtime (s)')
idx = np.round(np.linspace(0, len(df3['Relative error']) - 1, 10)).astype(int)
plot2.set(yticks=df3['Runtime'][idx])





# Packing all the plots and displaying them
plt.tight_layout()
plt.savefig('3.png', dpi=300, bbox_inches='tight')

# %%
#n=4
df4= pd.read_csv("C:/Users/carol/Desktop/RadBoudCode/out_4.txt", sep =';',names = ['Bandwidth','Compute rate (GFLOPS)','Relative error','Runtime'])
df4['MAX_ITER'] = range(1,1001)
df4['N'] = 4
df4
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER  N
# 0    1.#INF00              1.#INF00    9.917044e+01    0.000         1  4
# 1    1.#INF00              1.#INF00    7.934008e+03    0.000         2  4
# 2    1.#INF00              1.#INF00    6.362876e+05    0.000         3  4
# 3    1.#INF00              1.#INF00    5.102713e+07    0.000         4  4
# 4    1.#INF00              1.#INF00    4.092126e+09    0.000         5  4
# ..        ...                   ...             ...      ...       ... ..
# 995  1.#INF00              1.#INF00    1.611278e+54    0.000       996  4
# 996  1.#INF00              1.#INF00    1.611278e+54    0.001       997  4
# 997  1.#INF00              1.#INF00    1.611278e+54    0.000       998  4
# 998  1.#INF00              1.#INF00    1.611278e+54    0.000       999  4
# 999  1.#INF00              1.#INF00    1.611278e+54    0.001      1000  4
#
# [1000 rows x 6 columns]

# %%
df4_NaN = df4.replace(['1.#INF00','-1.#INF00'],np.nan)
df4_NaN = df4_NaN.dropna()
df4_NaN
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER  N
# 237  0.006650              0.003048    1.611278e+54    0.001       238  4
# 439  0.007500              0.003437    1.611278e+54    0.001       440  4
# 561  0.006347              0.002909    1.611278e+54    0.001       562  4
# 643  0.007657              0.003509    1.611278e+54    0.001       644  4
# 974  0.006531              0.002994    1.611278e+54    0.001       975  4

# %%
# Placing the plots in the plane
plot1 = plt.subplot2grid((6, 6), (0, 0), rowspan=2,colspan=2)
plot2 = plt.subplot2grid((6, 6), (0, 2), rowspan=4,colspan=2)
plot3 = plt.subplot2grid((6, 6), (2, 0), rowspan=2,colspan=2)
plot4 = plt.subplot2grid((6, 6), (0, 4), rowspan=4,colspan=2)
# Using Numpy to create an array x
x = np.arange(1, 1001)

# Plot for exponent
plot1.plot(x, df4['Bandwidth'],'.', markeredgewidth=0.02)
plot1.set_title('Bandwidth')
idx = np.round(np.linspace(0, len(df4['Bandwidth']) - 1, 10)).astype(int)
plot1.set(yticks=df4['Bandwidth'][idx])
plt.xlabel("Nº of interations for 4 x 4",fontsize=8)

# Plot for square root
plot4.plot(x, df4['Relative error'],'.', markeredgewidth=0.02)
plot4.set_title('Relative error')
plot4.set_yscale('log')


# Plot for Square
plot3.plot(x, df4['Compute rate (GFLOPS)'],'.', markeredgewidth=0.02)
plot3.set_title('Compute rate (GFLOPS)')
idx = np.round(np.linspace(0, len(df4['Compute rate (GFLOPS)']) - 1, 10)).astype(int)
plot3.set(yticks=df4['Compute rate (GFLOPS)'][idx])

# Plot for Square
plot2.plot(x, df4['Runtime'],'.', markeredgewidth=0.02)
plot2.set_title('Runtime (s)')
#idx = np.round(np.linspace(0, len(df4['Runtime']) - 1, 2)).astype(int)
#plot2.set(yticks=df4['Runtime'][idx])





# Packing all the plots and displaying them
plt.tight_layout()
plt.savefig('4.png', dpi=300, bbox_inches='tight')

# %%
#n=10
df10= pd.read_csv("C:/Users/carol/Desktop/RadBoudCode/out_10.txt", sep =';',names = ['Bandwidth','Compute rate (GFLOPS)','Relative error','Runtime'])
df10['MAX_ITER'] = range(1,1001)
df10['N'] = 10
df10
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER   N
# 0    1.#INF00              1.#INF00        0.794366    0.000         1  10
# 1    1.#INF00              1.#INF00        0.483582    0.000         2  10
# 2    1.#INF00              1.#INF00        0.289141    0.000         3  10
# 3    1.#INF00              1.#INF00        0.167807    0.001         4  10
# 4    1.#INF00              1.#INF00        0.092095    0.001         5  10
# ..        ...                   ...             ...      ...       ...  ..
# 995  1.#INF00              1.#INF00        0.033557    0.001       996  10
# 996  1.#INF00              1.#INF00        0.033557    0.001       997  10
# 997  1.#INF00              1.#INF00        0.033557    0.001       998  10
# 998  1.#INF00              1.#INF00        0.033557    0.001       999  10
# 999  1.#INF00              1.#INF00        0.033557    0.001      1000  10
#
# [1000 rows x 6 columns]

# %%
df10_NaN = df10.replace(['1.#INF00','-1.#INF00'],np.nan)
df10_NaN = df10_NaN.dropna()
df10_NaN
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER   N
# 79   0.137830              0.063172        0.033557    0.000        80  10
# 113  0.067171              0.030787        0.033557    0.001       114  10
# 154  0.069805              0.031994        0.033557    0.000       155  10
# 164  0.051787              0.023736        0.033557    0.001       165  10
# 178  0.067186              0.030794        0.033557    0.001       179  10
# 198  0.055247              0.025321        0.033557    0.001       199  10
# 225  0.049013              0.022464        0.033557    0.001       226  10
# 238  0.069821              0.032002        0.033557    0.000       239  10
# 263  0.069738              0.031963        0.033557    0.000       264  10
# 271  0.055018              0.025216        0.033557    0.001       272  10
# 276  0.069176              0.031706        0.033557    0.001       277  10
# ...

# %%
# Placing the plots in the plane
plot1 = plt.subplot2grid((6, 6), (0, 0), rowspan=2,colspan=2)
plot2 = plt.subplot2grid((6, 6), (0, 2), rowspan=4,colspan=2)
plot3 = plt.subplot2grid((6, 6), (2, 0), rowspan=2,colspan=2)
plot4 = plt.subplot2grid((6, 6), (0, 4), rowspan=4,colspan=2)
# Using Numpy to create an array x
x = np.arange(1, 1001)

# Plot for exponent
plot1.plot(x, df10['Bandwidth'],'.', markeredgewidth=0.02)
plot1.set_title('Bandwidth')
idx = np.round(np.linspace(0, len(df10['Bandwidth']) - 1, 10)).astype(int)
plot1.set(yticks=df10['Bandwidth'][idx])
plt.xlabel("Nº of interations for 10 x 10",fontsize=8)

# Plot for square root
plot4.plot(x, df10['Relative error'],'.', markeredgewidth=0.02)
plot4.set_title('Relative error')



# Plot for Square
plot3.plot(x, df10['Compute rate (GFLOPS)'],'.', markeredgewidth=0.02)
plot3.set_title('Compute rate (GFLOPS)')
idx = np.round(np.linspace(0, len(df10['Compute rate (GFLOPS)']) - 1, 10)).astype(int)
plot3.set(yticks=df10['Compute rate (GFLOPS)'][idx])

# Plot for Square
plot2.plot(x, df10['Runtime'],'.', markeredgewidth=0.02)
plot2.set_title('Runtime (s)')
idx = np.round(np.linspace(0, len(df10['Runtime']) - 1, 10)).astype(int)
plot2.set(yticks=df10['Runtime'][idx])





# Packing all the plots and displaying them
plt.tight_layout()
plt.savefig('10.png', dpi=300, bbox_inches='tight')

# %%
#n=25
df25= pd.read_csv("C:/Users/carol/Desktop/RadBoudCode/out_25.txt", sep =';',names = ['Bandwidth','Compute rate (GFLOPS)','Relative error','Runtime'])
df25['MAX_ITER'] = range(1,1001)
df25['N'] = 25
df25
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER   N
# 0    1.#INF00              1.#INF00        0.963062    0.000         1  25
# 1    1.#INF00              1.#INF00        0.897569    0.000         2  25
# 2    0.032774              0.015021        0.831599    0.001         3  25
# 3    1.#INF00              1.#INF00        0.768916    0.000         4  25
# 4    1.#INF00              1.#INF00        0.710200    0.000         5  25
# ..        ...                   ...             ...      ...       ...  ..
# 995  2.304290              1.056133        0.005398    0.002       996  25
# 996  2.331840              1.068760        0.005398    0.000       997  25
# 997  2.334632              1.070040        0.005398    0.000       998  25
# 998  2.334073              1.069783        0.005398    0.001       999  25
# 999  2.334632              1.070040        0.005398    0.001      1000  25
#
# [1000 rows x 6 columns]

# %%
# Placing the plots in the plane
plot1 = plt.subplot2grid((6, 6), (0, 0), rowspan=2,colspan=2)
plot2 = plt.subplot2grid((6, 6), (0, 2), rowspan=4,colspan=2)
plot3 = plt.subplot2grid((6, 6), (2, 0), rowspan=2,colspan=2)
plot4 = plt.subplot2grid((6, 6), (0, 4), rowspan=4,colspan=2)
# Using Numpy to create an array x
x = np.arange(1, 1001)

# Plot for exponent
plot1.plot(x, df25['Bandwidth'],'.', markeredgewidth=0.02)
plot1.set_title('Bandwidth')
idx = np.round(np.linspace(0, len(df25['Bandwidth'])-1, 20)).astype(int)
plot1.set(yticks=df25['Bandwidth'][idx])
plt.xlabel("Nº of interations for 25 x 25",fontsize=8)

# Plot for square root
plot4.plot(x, df25['Relative error'],'.', markeredgewidth=0.02)
plot4.set_title('Relative error')



# Plot for Square
plot3.plot(x, df25['Compute rate (GFLOPS)'],'.', markeredgewidth=0.02)
plot3.set_title('Compute rate (GFLOPS)')
idx = np.round(np.linspace(0, len(df25['Compute rate (GFLOPS)']) - 1, 20)).astype(int)
plot3.set(yticks=df25['Compute rate (GFLOPS)'][idx])

# Plot for Square
plot2.plot(x, df25['Runtime'],'.', markeredgewidth=0.02)
plot2.set_title('Runtime (s)')
#idx = np.round(np.linspace(0, len(df25['Runtime']) - 1, 10)).astype(int)
#plot2.set(yticks=df25['Runtime'][idx])





# Packing all the plots and displaying them
plt.tight_layout()
plt.savefig('25.png', dpi=300, bbox_inches='tight')

# %%
np.min(df25['Relative error'])
# Out:
# np.float64(0.005397682)

# %%
df25[df25['Compute rate (GFLOPS)'] == np.min(df25['Compute rate (GFLOPS)'])]
# Out:
#      Bandwidth Compute rate (GFLOPS)  Relative error  Runtime
# 6950  0.352698              0.161653        0.005398    0.009

# %%
df25_NaN = df25.replace(['1.#INF00','-1.#INF00'],np.nan)
df25_NaN = df25_NaN.dropna()
df25_NaN
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER   N
# 2    0.032774              0.015021        0.831599    0.001         3  25
# 15   0.240476              0.110218        0.292478    0.000        16  25
# 25   0.767611              0.351822        0.130929    0.000        26  25
# 30   0.465034              0.213140        0.087769    0.000        31  25
# 32   0.515181              0.236125        0.074792    0.003        33  25
# ..        ...                   ...             ...      ...       ...  ..
# 995  2.304290              1.056133        0.005398    0.002       996  25
# 996  2.331840              1.068760        0.005398    0.000       997  25
# 997  2.334632              1.070040        0.005398    0.000       998  25
# 998  2.334073              1.069783        0.005398    0.001       999  25
# 999  2.334632              1.070040        0.005398    0.001      1000  25
#
# [866 rows x 6 columns]

# %%
#n=50
df50= pd.read_csv("C:/Users/carol/Desktop/RadBoudCode/out_50.txt", sep =';',names = ['Bandwidth','Compute rate (GFLOPS)','Relative error','Runtime'])
df50['MAX_ITER'] = range(1,1001)
df50['N'] = 50
df50
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER   N
# 0    1.#INF00              1.#INF00        0.988595    0.001         1  50
# 1    1.#INF00              1.#INF00        0.953898    0.002         2  50
# 2    1.#INF00              1.#INF00        0.915737    0.002         3  50
# 3    1.#INF00              1.#INF00        0.878143    0.001         4  50
# 4    1.#INF00              1.#INF00        0.841893    0.001         5  50
# ..        ...                   ...             ...      ...       ...  ..
# 995  2.719278              1.246336        0.001317    0.012       996  50
# 996  2.584041              1.184352        0.001317    0.011       997  50
# 997  2.832291              1.298134        0.001317    0.012       998  50
# 998  2.731639              1.252001        0.001317    0.012       999  50
# 999  2.312777              1.060023        0.001317    0.013      1000  50
#
# [1000 rows x 6 columns]

# %%
# Placing the plots in the plane
plot1 = plt.subplot2grid((6, 6), (0, 0), rowspan=2,colspan=2)
plot2 = plt.subplot2grid((6, 6), (0, 2), rowspan=4,colspan=2)
plot3 = plt.subplot2grid((6, 6), (2, 0), rowspan=2,colspan=2)
plot4 = plt.subplot2grid((6, 6), (0, 4), rowspan=4,colspan=2)
# Using Numpy to create an array x
x = np.arange(1, 1001)

# Plot for exponent
plot1.plot(x, df50['Bandwidth'],'.', markeredgewidth=0.02)
plot1.set_title('Bandwidth')
idx = np.round(np.linspace(0, len(df50['Bandwidth']) - 1, 10)).astype(int)
plot1.set(yticks=df50['Bandwidth'][idx])
plt.xlabel("Nº of interations for 50 x 50",fontsize=8)

# Plot for square root
plot4.plot(x, df50['Relative error'],'.', markeredgewidth=0.02)
plot4.set_title('Relative error')



# Plot for Square
plot3.plot(x, df50['Compute rate (GFLOPS)'],'.', markeredgewidth=0.02)
plot3.set_title('Compute rate (GFLOPS)')
idx = np.round(np.linspace(0, len(df50['Compute rate (GFLOPS)']) - 1, 10)).astype(int)
plot3.set(yticks=df50['Compute rate (GFLOPS)'][idx])

# Plot for Square
plot2.plot(x, df50['Runtime'],'.', markeredgewidth=0.02)
plot2.set_title('Runtime (s)')
idx = np.round(np.linspace(0, len(df50['Relative error']) - 1, 10)).astype(int)
plot2.set(yticks=df50['Runtime'][idx])





# Packing all the plots and displaying them
plt.tight_layout()
plt.savefig('50.png', dpi=300, bbox_inches='tight')

# %%
df50.replace(['1.#INF00','-1.#INF00'],np.nan).corr(method='pearson')

# %%
#n=75
df75= pd.read_csv("C:/Users/carol/Desktop/RadBoudCode/out_75.txt", sep =';',names = ['Bandwidth','Compute rate (GFLOPS)','Relative error','Runtime'])
df75['MAX_ITER'] = range(1,1001)
df75['N'] = 75
df75
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER   N
# 0    1.#INF00              1.#INF00        0.994431    0.002         1  75
# 1    1.#INF00              1.#INF00        0.980176    0.003         2  75
# 2    1.#INF00              1.#INF00        0.962306    0.002         3  75
# 3    1.#INF00              1.#INF00        0.942972    0.001         4  75
# 4    0.655967              0.300652        0.922927    0.001         5  75
# ..        ...                   ...             ...      ...       ...  ..
# 995  2.564525              1.175407        0.000586    0.052       996  75
# 996  2.632199              1.206425        0.000586    0.050       997  75
# 997  2.937469              1.346340        0.000586    0.044       998  75
# 998  2.778847              1.273638        0.000586    0.046       999  75
# 999  2.902182              1.330167        0.000586    0.045      1000  75
#
# [1000 rows x 6 columns]

# %%
# Placing the plots in the plane
plot1 = plt.subplot2grid((6, 6), (0, 0), rowspan=2,colspan=2)
plot2 = plt.subplot2grid((6, 6), (0, 2), rowspan=4,colspan=2)
plot3 = plt.subplot2grid((6, 6), (2, 0), rowspan=2,colspan=2)
plot4 = plt.subplot2grid((6, 6), (0, 4), rowspan=4,colspan=2)
# Using Numpy to create an array x
x = np.arange(1, 1001)

# Plot for exponent
plot1.plot(x, df75['Bandwidth'],'.', markeredgewidth=0.02)
plot1.set_title('Bandwidth')
idx = np.round(np.linspace(0, len(df75['Bandwidth']) - 1, 10)).astype(int)
plot1.set(yticks=df75['Bandwidth'][idx])
plt.xlabel("Nº of interations for 75 x 75",fontsize=8)

# Plot for square root
plot4.plot(x, df75['Relative error'],'.', markeredgewidth=0.02)
plot4.set_title('Relative error')



# Plot for Square
plot3.plot(x, df75['Compute rate (GFLOPS)'],'.', markeredgewidth=0.02)
plot3.set_title('Compute rate (GFLOPS)')
idx = np.round(np.linspace(0, len(df75['Compute rate (GFLOPS)']) - 1, 10)).astype(int)
plot3.set(yticks=df75['Compute rate (GFLOPS)'][idx])

# Plot for Square
plot2.plot(x, df75['Runtime'],'.', markeredgewidth=0.02)
plot2.set_title('Runtime (s)')
idx = np.round(np.linspace(0, len(df75['Runtime']) - 1, 10)).astype(int)
plot2.set(yticks=df75['Runtime'][idx])





# Packing all the plots and displaying them
plt.tight_layout()
plt.savefig('75.png', dpi=300, bbox_inches='tight')

# %%
# plot
fig, ax = plt.subplots()
ax.plot(df75['Bandwidth'], df75['Relative error'],'.', markeredgewidth=0.02,color='C1')
idx = np.round(np.linspace(0, len(df75['Bandwidth']) - 1, 5)).astype(int)
plt.xticks(idx, df75['Bandwidth'][idx])
plt.show()

# %%
#n=100
df100= pd.read_csv("C:/Users/carol/Desktop/RadBoudCode/out_100.txt", sep =';',names = ['Bandwidth','Compute rate (GFLOPS)','Relative error','Runtime'])
df100['MAX_ITER'] = range(1,1001)
df100['N'] = 100
df100
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER    N
# 0    1.#INF00              1.#INF00        0.994733    0.003         1  100
# 1    1.#INF00              1.#INF00        0.982276    0.004         2  100
# 2    1.#INF00              1.#INF00        0.965818    0.002         3  100
# 3    0.961904              0.440873        0.947734    0.003         4  100
# 4    1.#INF00              1.#INF00        0.929115    0.003         5  100
# ..        ...                   ...             ...      ...       ...  ...
# 995  2.473635              1.133750        0.000329    0.099       996  100
# 996  2.616826              1.199379        0.000329    0.095       997  100
# 997  2.802224              1.284353        0.000329    0.088       998  100
# 998  2.668357              1.222997        0.000329    0.092       999  100
# 999  2.867181              1.314125        0.000329    0.085      1000  100
#
# [1000 rows x 6 columns]

# %%
# Placing the plots in the plane
plot1 = plt.subplot2grid((6, 6), (0, 0), rowspan=2,colspan=2)
plot2 = plt.subplot2grid((6, 6), (0, 2), rowspan=4,colspan=2)
plot3 = plt.subplot2grid((6, 6), (2, 0), rowspan=2,colspan=2)
plot4 = plt.subplot2grid((6, 6), (0, 4), rowspan=4,colspan=2)
# Using Numpy to create an array x
x = np.arange(1, 1001)

# Plot for exponent
plot1.plot(x, df100['Bandwidth'],'.', markeredgewidth=0.02)
plot1.set_title('Bandwidth')
idx = np.round(np.linspace(0, len(df100['Bandwidth']) - 1, 10)).astype(int)
plot1.set(yticks=df100['Bandwidth'][idx])
plt.xlabel("Nº of interations for 100 x 100",fontsize=8)

# Plot for square root
plot4.plot(x, df100['Relative error'],'.', markeredgewidth=0.02)
plot4.set_title('Relative error')



# Plot for Square
plot3.plot(x, df100['Compute rate (GFLOPS)'],'.', markeredgewidth=0.02)
plot3.set_title('Compute rate (GFLOPS)')
idx = np.round(np.linspace(0, len(df100['Compute rate (GFLOPS)']) - 1, 10)).astype(int)
plot3.set(yticks=df100['Compute rate (GFLOPS)'][idx])

# Plot for Square
plot2.plot(x, df100['Runtime'],'.', markeredgewidth=0.02)
plot2.set_title('Runtime (s)')
idx = np.round(np.linspace(0, len(df100['Runtime']) - 1, 10)).astype(int)
plot2.set(yticks=df100['Runtime'][idx])





# Packing all the plots and displaying them
plt.tight_layout()
plt.savefig('100.png', dpi=300, bbox_inches='tight')

# %%
#n=1000
df1000= pd.read_csv("C:/Users/carol/Desktop/RadBoudCode/out_100.txt", sep =';',names = ['Bandwidth','Compute rate (GFLOPS)','Relative error','Runtime'])
df1000['MAX_ITER'] = range(1,1001)
df1000['N'] = 1000
df1000
# Out:
#     Bandwidth Compute rate (GFLOPS)  Relative error  Runtime  MAX_ITER     N
# 0    1.#INF00              1.#INF00        0.994733    0.003         1  1000
# 1    1.#INF00              1.#INF00        0.982276    0.004         2  1000
# 2    1.#INF00              1.#INF00        0.965818    0.002         3  1000
# 3    0.961904              0.440873        0.947734    0.003         4  1000
# 4    1.#INF00              1.#INF00        0.929115    0.003         5  1000
# ..        ...                   ...             ...      ...       ...   ...
# 995  2.473635              1.133750        0.000329    0.099       996  1000
# 996  2.616826              1.199379        0.000329    0.095       997  1000
# 997  2.802224              1.284353        0.000329    0.088       998  1000
# 998  2.668357              1.222997        0.000329    0.092       999  1000
# 999  2.867181              1.314125        0.000329    0.085      1000  1000
#
# [1000 rows x 6 columns]

# %%
# Placing the plots in the plane
plot1 = plt.subplot2grid((6, 6), (0, 0), rowspan=2,colspan=2)
plot2 = plt.subplot2grid((6, 6), (0, 2), rowspan=4,colspan=2)
plot3 = plt.subplot2grid((6, 6), (2, 0), rowspan=2,colspan=2)
plot4 = plt.subplot2grid((6, 6), (0, 4), rowspan=4,colspan=2)
# Using Numpy to create an array x
x = np.arange(1, 1001)

# Plot for exponent
plot1.plot(x, df1000['Bandwidth'],'.', markeredgewidth=0.02)
plot1.set_title('Bandwidth')
idx = np.round(np.linspace(0, len(df1000['Bandwidth']) - 1, 10)).astype(int)
plot1.set(yticks=df1000['Bandwidth'][idx])
plt.xlabel("Nº of interations for 1000 x 1000",fontsize=8)

# Plot for square root
plot4.plot(x, df1000['Relative error'],'.', markeredgewidth=0.02)
plot4.set_title('Relative error')



# Plot for Square
plot3.plot(x, df1000['Compute rate (GFLOPS)'],'.', markeredgewidth=0.02)
plot3.set_title('Compute rate (GFLOPS)')
idx = np.round(np.linspace(0, len(df1000['Compute rate (GFLOPS)']) - 1, 10)).astype(int)
plot3.set(yticks=df1000['Compute rate (GFLOPS)'][idx])

# Plot for Square
plot2.plot(x, df1000['Runtime'],'.', markeredgewidth=0.02)
plot2.set_title('Runtime (s)')
idx = np.round(np.linspace(0, len(df1000['Runtime']) - 1, 10)).astype(int)
plot2.set(yticks=df1000['Runtime'][idx])





# Packing all the plots and displaying them
plt.tight_layout()

plt.savefig('1000.png', dpi=300, bbox_inches='tight')
